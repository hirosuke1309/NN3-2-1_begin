# %%
import pulp
import time
import itertools
from ortoolpy import addvars

# %%
#processing_time
p=[1, 93, 26, 30, 93, 76]
#    , 48, 90, 98, 27, 78, 42, 75, 79, 79, 43, 95, 80, 83, 10]
# weight
w=[1, 3, 3, 5, 9, 7]
#    , 3, 9, 10, 4, 8, 7, 9, 2, 10, 9, 5, 4, 1, 9]
# relase_time
r=[63,4,63,99,73,20]
#    ,37,40,77,112,62,36,52,22,9,6,51,76,219,118]
job_num=6
# job_list=list(range(6))

problem = pulp.LpProblem("optimization_report_1", pulp.LpMinimize)
# pulp.LpMinimize : 最小化
# pulp.LpMaximize : 最大化

# %%
# 変数宣言
# lowBound, upBound を指定しないと、それぞれ -無限大, +無限大 になる
# pulp.LpContinuous : 連続変数
# pulp.LpInteger : 整数変数
# pulp.LpBinary : 0-1変数

x=[[0 for k in range(job_num)]for j in range(job_num)]
    
for j in range(job_num):
    for k in range(job_num):
#         if k!=j:
            x[j][k] = pulp.LpVariable(f"x({j},{k})", 0, 1, pulp.LpInteger)
print(x)
# Out:
# [[x(0,0), x(0,1), x(0,2), x(0,3), x(0,4), x(0,5)], [x(1,0), x(1,1), x(1,2), x(1,3), x(1,4), x(1,5)], [x(2,0), x(2,1), x(2,2), x(2,3), x(2,4), x(2,5)], [x(3,0), x(3,1), x(3,2), x(3,3), x(3,4), x(3,5)], [x(4,0), x(4,1), x(4,2), x(4,3), x(4,4), x(4,5)], [x(5,0), x(5,1), x(5,2), x(5,3), x(5,4), x(5,5)]]

# %% [markdown]
# x=[[0 for k in range(job_num-1)]for j in range(job_num)]
#
# for j in range(job_num):
#     job_list=list(range(len(r)))
#     job_list.remove(j)
# #     print(type(job_list))
#     print(job_list)
#     for k in job_list:
#         x[j][k] = pulp.LpVariable(f"x({j},{k})", 0, 1, pulp.LpInteger)
# # print(x)

# %%
# c=addvars(len(r),cat='Integer')
c
# Out:
# [v000187, v000188, v000189, v000190, v000191, v000192]

# %%
c=addvars(len(r),cat='Integer')
s=addvars(len(r),cat='Integer')
s
# Out:
# [v000205, v000206, v000207, v000208, v000209, v000210]

# %%
# 目的関数
problem+= sum(w[j] * (s[j]+p[j]) for j in range(len(r)))

# %%
# 制約条件
for j in range(job_num):
    problem += s[j] >= r[j]
list=[]
M=max(r)+sum(p)
for j in range(len(r)):
    for k in range(len(r)):
        problem += s[j]+p[j] <= s[k] + M*(1-x[j][k])
for j in range(job_num):
    for k in range(job_num):
        if k != j:
            problem += x[j][k] + x[k][j] == 1

# %%
problem
# Out:
# optimization_report_1:
# MINIMIZE
# 1*v000205 + 3*v000206 + 3*v000207 + 5*v000208 + 9*v000209 + 7*v000210 + 1877
# SUBJECT TO
# _C1: v000157 >= 63
#
# _C2: v000158 >= 4
#
# _C3: v000159 >= 63
#
# _C4: v000160 >= 99
#
# _C5: v000161 >= 73
#
# _C6: v000162 >= 20
#
# _C7: 0 v000157 + 418 x(0,0) <= 417
#
# _C8: v000157 - v000158 + 418 x(0,1) <= 417
#
# _C9: v000157 - v000159 + 418 x(0,2) <= 417
#
# _C10: v000157 - v000160 + 418 x(0,3) <= 417
#
# _C11: v000157 - v000161 + 418 x(0,4) <= 417
#
# _C12: v000157 - v000162 + 418 x(0,5) <= 417
#
# _C13: - v000157 + v000158 + 418 x(1,0) <= 325
#
# _C14: 0 v000158 + 418 x(1,1) <= 325
#
# _C15: v000158 - v000159 + 418 x(1,2) <= 325
#
# _C16: v000158 - v000160 + 418 x(1,3) <= 325
#
# _C17: v000158 - v000161 + 418 x(1,4) <= 325
#
# _C18: v000158 - v000162 + 418 x(1,5) <= 325
#
# _C19: - v000157 + v000159 + 418 x(2,0) <= 392
#
# _C20: - v000158 + v000159 + 418 x(2,1) <= 392
#
# _C21: 0 v000159 + 418 x(2,2) <= 392
#
# _C22: v000159 - v000160 + 418 x(2,3) <= 392
#
# _C23: v000159 - v000161 + 418 x(2,4) <= 392
#
# _C24: v000159 - v000162 + 418 x(2,5) <= 392
#
# _C25: - v000157 + v000160 + 418 x(3,0) <= 388
#
# _C26: - v000158 + v000160 + 418 x(3,1) <= 388
#
# _C27: - v000159 + v000160 + 418 x(3,2) <= 388
#
# _C28: 0 v000160 + 418 x(3,3) <= 388
#
# _C29: v000160 - v000161 + 418 x(3,4) <= 388
#
# _C30: v000160 - v000162 + 418 x(3,5) <= 388
#
# _C31: - v000157 + v000161 + 418 x(4,0) <= 325
#
# _C32: - v000158 + v000161 + 418 x(4,1) <= 325
#
# _C33: - v000159 + v000161 + 418 x(4,2) <= 325
#
# _C34: - v000160 + v000161 + 418 x(4,3) <= 325
#
# _C35: 0 v000161 + 418 x(4,4) <= 325
#
# _C36: v000161 - v000162 + 418 x(4,5) <= 325
#
# _C37: - v000157 + v000162 + 418 x(5,0) <= 342
#
# _C38: - v000158 + v000162 + 418 x(5,1) <= 342
#
# _C39: - v000159 + v000162 + 418 x(5,2) <= 342
#
# _C40: - v000160 + v000162 + 418 x(5,3) <= 342
#
# _C41: - v000161 + v000162 + 418 x(5,4) <= 342
#
# _C42: 0 v000162 + 418 x(5,5) <= 342
#
# _C43: x(0,1) + x(1,0) = 1
#
# _C44: x(0,2) + x(2,0) = 1
#
# _C45: x(0,3) + x(3,0) = 1
#
# _C46: x(0,4) + x(4,0) = 1
#
# _C47: x(0,5) + x(5,0) = 1
#
# _C48: x(0,1) + x(1,0) = 1
#
# _C49: x(1,2) + x(2,1) = 1
#
# _C50: x(1,3) + x(3,1) = 1
#
# _C51: x(1,4) + x(4,1) = 1
#
# _C52: x(1,5) + x(5,1) = 1
#
# _C53: x(0,2) + x(2,0) = 1
#
# _C54: x(1,2) + x(2,1) = 1
#
# _C55: x(2,3) + x(3,2) = 1
#
# _C56: x(2,4) + x(4,2) = 1
#
# _C57: x(2,5) + x(5,2) = 1
#
# _C58: x(0,3) + x(3,0) = 1
#
# _C59: x(1,3) + x(3,1) = 1
#
# _C60: x(2,3) + x(3,2) = 1
#
# _C61: x(3,4) + x(4,3) = 1
#
# _C62: x(3,5) + x(5,3) = 1
#
# _C63: x(0,4) + x(4,0) = 1
#
# _C64: x(1,4) + x(4,1) = 1
#
# _C65: x(2,4) + x(4,2) = 1
#
# _C66: x(3,4) + x(4,3) = 1
#
# _C67: x(4,5) + x(5,4) = 1
#
# _C68: x(0,5) + x(5,0) = 1
#
# _C69: x(1,5) + x(5,1) = 1
#
# _C70: x(2,5) + x(5,2) = 1
#
# _C71: x(3,5) + x(5,3) = 1
#
# _C72: x(4,5) + x(5,4) = 1
#
# _C73: v000157 >= 63
#
# _C74: v000158 >= 4
#
# _C75: v000159 >= 63
#
# _C76: v000160 >= 99
#
# _C77: v000161 >= 73
#
# _C78: v000162 >= 20
#
# _C79: 0 v000157 + 418 x(0,0) <= 417
#
# _C80: v000157 - v000158 + 418 x(0,1) <= 417
#
# _C81: v000157 - v000159 + 418 x(0,2) <= 417
#
# _C82: v000157 - v000160 + 418 x(0,3) <= 417
#
# _C83: v000157 - v000161 + 418 x(0,4) <= 417
#
# _C84: v000157 - v000162 + 418 x(0,5) <= 417
#
# _C85: - v000157 + v000158 + 418 x(1,0) <= 325
#
# _C86: 0 v000158 + 418 x(1,1) <= 325
#
# _C87: v000158 - v000159 + 418 x(1,2) <= 325
#
# _C88: v000158 - v000160 + 418 x(1,3) <= 325
#
# _C89: v000158 - v000161 + 418 x(1,4) <= 325
#
# _C90: v000158 - v000162 + 418 x(1,5) <= 325
#
# _C91: - v000157 + v000159 + 418 x(2,0) <= 392
#
# _C92: - v000158 + v000159 + 418 x(2,1) <= 392
#
# _C93: 0 v000159 + 418 x(2,2) <= 392
#
# _C94: v000159 - v000160 + 418 x(2,3) <= 392
#
# _C95: v000159 - v000161 + 418 x(2,4) <= 392
#
# _C96: v000159 - v000162 + 418 x(2,5) <= 392
#
# _C97: - v000157 + v000160 + 418 x(3,0) <= 388
#
# _C98: - v000158 + v000160 + 418 x(3,1) <= 388
#
# _C99: - v000159 + v000160 + 418 x(3,2) <= 388
#
# _C100: 0 v000160 + 418 x(3,3) <= 388
#
# _C101: v000160 - v000161 + 418 x(3,4) <= 388
#
# _C102: v000160 - v000162 + 418 x(3,5) <= 388
#
# _C103: - v000157 + v000161 + 418 x(4,0) <= 325
#
# _C104: - v000158 + v000161 + 418 x(4,1) <= 325
#
# _C105: - v000159 + v000161 + 418 x(4,2) <= 325
#
# _C106: - v000160 + v000161 + 418 x(4,3) <= 325
#
# _C107: 0 v000161 + 418 x(4,4) <= 325
#
# _C108: v000161 - v000162 + 418 x(4,5) <= 325
#
# _C109: - v000157 + v000162 + 418 x(5,0) <= 342
#
# _C110: - v000158 + v000162 + 418 x(5,1) <= 342
#
# _C111: - v000159 + v000162 + 418 x(5,2) <= 342
#
# _C112: - v000160 + v000162 + 418 x(5,3) <= 342
#
# _C113: - v000161 + v000162 + 418 x(5,4) <= 342
#
# _C114: 0 v000162 + 418 x(5,5) <= 342
#
# _C115: x(0,1) + x(1,0) = 1
#
# _C116: x(0,2) + x(2,0) = 1
#
# _C117: x(0,3) + x(3,0) = 1
#
# _C118: x(0,4) + x(4,0) = 1
#
# _C119: x(0,5) + x(5,0) = 1
#
# _C120: x(0,1) + x(1,0) = 1
#
# _C121: x(1,2) + x(2,1) = 1
#
# _C122: x(1,3) + x(3,1) = 1
#
# _C123: x(1,4) + x(4,1) = 1
#
# _C124: x(1,5) + x(5,1) = 1
#
# _C125: x(0,2) + x(2,0) = 1
#
# _C126: x(1,2) + x(2,1) = 1
#
# _C127: x(2,3) + x(3,2) = 1
#
# _C128: x(2,4) + x(4,2) = 1
#
# _C129: x(2,5) + x(5,2) = 1
#
# _C130: x(0,3) + x(3,0) = 1
#
# _C131: x(1,3) + x(3,1) = 1
#
# _C132: x(2,3) + x(3,2) = 1
#
# _C133: x(3,4) + x(4,3) = 1
#
# _C134: x(3,5) + x(5,3) = 1
#
# _C135: x(0,4) + x(4,0) = 1
#
# _C136: x(1,4) + x(4,1) = 1
#
# _C137: x(2,4) + x(4,2) = 1
#
# _C138: x(3,4) + x(4,3) = 1
#
# _C139: x(4,5) + x(5,4) = 1
#
# _C140: x(0,5) + x(5,0) = 1
#
# _C141: x(1,5) + x(5,1) = 1
#
# _C142: x(2,5) + x(5,2) = 1
#
# _C143: x(3,5) + x(5,3) = 1
#
# _C144: x(4,5) + x(5,4) = 1
#
# _C145: v000205 >= 63
#
# _C146: v000206 >= 4
#
# _C147: v000207 >= 63
#
# _C148: v000208 >= 99
#
# _C149: v000209 >= 73
#
# _C150: v000210 >= 20
#
# _C151: 0 v000205 + 418 x(0,0) <= 417
#
# _C152: v000205 - v000206 + 418 x(0,1) <= 417
#
# _C153: v000205 - v000207 + 418 x(0,2) <= 417
#
# _C154: v000205 - v000208 + 418 x(0,3) <= 417
#
# _C155: v000205 - v000209 + 418 x(0,4) <= 417
#
# _C156: v000205 - v000210 + 418 x(0,5) <= 417
#
# _C157: - v000205 + v000206 + 418 x(1,0) <= 325
#
# _C158: 0 v000206 + 418 x(1,1) <= 325
#
# _C159: v000206 - v000207 + 418 x(1,2) <= 325
#
# _C160: v000206 - v000208 + 418 x(1,3) <= 325
#
# _C161: v000206 - v000209 + 418 x(1,4) <= 325
#
# _C162: v000206 - v000210 + 418 x(1,5) <= 325
#
# _C163: - v000205 + v000207 + 418 x(2,0) <= 392
#
# _C164: - v000206 + v000207 + 418 x(2,1) <= 392
#
# _C165: 0 v000207 + 418 x(2,2) <= 392
#
# _C166: v000207 - v000208 + 418 x(2,3) <= 392
#
# _C167: v000207 - v000209 + 418 x(2,4) <= 392
#
# _C168: v000207 - v000210 + 418 x(2,5) <= 392
#
# _C169: - v000205 + v000208 + 418 x(3,0) <= 388
#
# _C170: - v000206 + v000208 + 418 x(3,1) <= 388
#
# _C171: - v000207 + v000208 + 418 x(3,2) <= 388
#
# _C172: 0 v000208 + 418 x(3,3) <= 388
#
# _C173: v000208 - v000209 + 418 x(3,4) <= 388
#
# _C174: v000208 - v000210 + 418 x(3,5) <= 388
#
# _C175: - v000205 + v000209 + 418 x(4,0) <= 325
#
# _C176: - v000206 + v000209 + 418 x(4,1) <= 325
#
# _C177: - v000207 + v000209 + 418 x(4,2) <= 325
#
# _C178: - v000208 + v000209 + 418 x(4,3) <= 325
#
# _C179: 0 v000209 + 418 x(4,4) <= 325
#
# _C180: v000209 - v000210 + 418 x(4,5) <= 325
#
# _C181: - v000205 + v000210 + 418 x(5,0) <= 342
#
# _C182: - v000206 + v000210 + 418 x(5,1) <= 342
#
# _C183: - v000207 + v000210 + 418 x(5,2) <= 342
#
# _C184: - v000208 + v000210 + 418 x(5,3) <= 342
#
# _C185: - v000209 + v000210 + 418 x(5,4) <= 342
#
# _C186: 0 v000210 + 418 x(5,5) <= 342
#
# _C187: x(0,1) + x(1,0) = 1
#
# _C188: x(0,2) + x(2,0) = 1
#
# _C189: x(0,3) + x(3,0) = 1
#
# _C190: x(0,4) + x(4,0) = 1
#
# _C191: x(0,5) + x(5,0) = 1
#
# _C192: x(0,1) + x(1,0) = 1
#
# _C193: x(1,2) + x(2,1) = 1
#
# _C194: x(1,3) + x(3,1) = 1
#
# _C195: x(1,4) + x(4,1) = 1
#
# _C196: x(1,5) + x(5,1) = 1
#
# _C197: x(0,2) + x(2,0) = 1
#
# _C198: x(1,2) + x(2,1) = 1
#
# _C199: x(2,3) + x(3,2) = 1
#
# _C200: x(2,4) + x(4,2) = 1
#
# _C201: x(2,5) + x(5,2) = 1
#
# _C202: x(0,3) + x(3,0) = 1
#
# _C203: x(1,3) + x(3,1) = 1
#
# _C204: x(2,3) + x(3,2) = 1
#
# _C205: x(3,4) + x(4,3) = 1
#
# _C206: x(3,5) + x(5,3) = 1
#
# _C207: x(0,4) + x(4,0) = 1
#
# _C208: x(1,4) + x(4,1) = 1
#
# _C209: x(2,4) + x(4,2) = 1
#
# _C210: x(3,4) + x(4,3) = 1
#
# _C211: x(4,5) + x(5,4) = 1
#
# _C212: x(0,5) + x(5,0) = 1
#
# _C213: x(1,5) + x(5,1) = 1
#
# _C214: x(2,5) + x(5,2) = 1
#
# _C215: x(3,5) + x(5,3) = 1
#
# _C216: x(4,5) + x(5,4) = 1
#
# VARIABLES
# 0 <= v000157 Integer
# 0 <= v000158 Integer
# 0 <= v000159 Integer
# 0 <= v000160 Integer
# 0 <= v000161 Integer
# 0 <= v000162 Integer
# 0 <= v000205 Integer
# 0 <= v000206 Integer
# 0 <= v000207 Integer
# 0 <= v000208 Integer
# 0 <= v000209 Integer
# 0 <= v000210 Integer
# 0 <= x(0,0) <= 1 Integer
# 0 <= x(0,1) <= 1 Integer
# 0 <= x(0,2) <= 1 Integer
# 0 <= x(0,3) <= 1 Integer
# 0 <= x(0,4) <= 1 Integer
# 0 <= x(0,5) <= 1 Integer
# 0 <= x(1,0) <= 1 Integer
# 0 <= x(1,1) <= 1 Integer
# 0 <= x(1,2) <= 1 Integer
# 0 <= x(1,3) <= 1 Integer
# 0 <= x(1,4) <= 1 Integer
# 0 <= x(1,5) <= 1 Integer
# 0 <= x(2,0) <= 1 Integer
# 0 <= x(2,1) <= 1 Integer
# 0 <= x(2,2) <= 1 Integer
# 0 <= x(2,3) <= 1 Integer
# 0 <= x(2,4) <= 1 Integer
# 0 <= x(2,5) <= 1 Integer
# 0 <= x(3,0) <= 1 Integer
# 0 <= x(3,1) <= 1 Integer
# 0 <= x(3,2) <= 1 Integer
# 0 <= x(3,3) <= 1 Integer
# 0 <= x(3,4) <= 1 Integer
# 0 <= x(3,5) <= 1 Integer
# 0 <= x(4,0) <= 1 Integer
# 0 <= x(4,1) <= 1 Integer
# 0 <= x(4,2) <= 1 Integer
# 0 <= x(4,3) <= 1 Integer
# 0 <= x(4,4) <= 1 Integer
# 0 <= x(4,5) <= 1 Integer
# 0 <= x(5,0) <= 1 Integer
# 0 <= x(5,1) <= 1 Integer
# 0 <= x(5,2) <= 1 Integer
# 0 <= x(5,3) <= 1 Integer
# 0 <= x(5,4) <= 1 Integer
# 0 <= x(5,5) <= 1 Integer

# %%
time_start = time.perf_counter()
status = ploblem.solve()
# 時間計測終了
time_stop = time.perf_counter()
print(pulp.LpStatus[status])
# for k in range(job_num):
#     for j in range(job_num):
#         print('complete time of job'+str(j)+':' , c[j].value())
print("Obj.value", problem.objective.value())
print("time:", time_stop-time_start)
# Out:
# Optimal
# Obj.value None
# time: 0.09964392199981376

# %%
for a in list(range(6)):
    print(a)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for k in job_list: 
    print(k)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a
# Out:
# [0, 1, 2, 4, 5]
